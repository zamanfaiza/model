# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import random
from tqdm import tqdm
import cv2

# %%
Data_path="C:\model train\Imagedata"

# %%
classes=os.listdir(Data_path)
train_data=[]

for i,c in enumerate(classes):
    path = os.path.join(Data_path,c)
    for img in tqdm(os.listdir(path)):
        img_arr = cv2.imread(os.path.join(path,img))
        img_arr = cv2.resize(img_arr,(64,64))
        train_data.append([img_arr,i])
print(len(train_data))
# Out:
# 100%|██████████| 20/20 [00:02<00:00,  8.20it/s]
# 100%|██████████| 26/26 [00:00<00:00, 32.33it/s]
# 100%|██████████| 8/8 [00:00<00:00, 47.36it/s]
# 100%|██████████| 8/8 [00:00<00:00, 25.05it/s]
# 100%|██████████| 28/28 [00:00<00:00, 254.38it/s]
# 100%|██████████| 10/10 [00:00<00:00, 11.10it/s]
# 100%|██████████| 10/10 [00:00<00:00, 15.49it/s]
# 100%|██████████| 26/26 [00:02<00:00, 12.60it/s]
# 100%|██████████| 12/12 [00:01<00:00, 11.26it/s]
# 100%|██████████| 32/32 [00:01<00:00, 16.88it/s]
# 100%|██████████| 10/10 [00:00<00:00, 58.45it/s]
# 100%|██████████| 10/10 [00:00<00:00, 19.77it/s]
# 100%|██████████| 10/10 [00:01<00:00,  9.24it/s]
# 100%|██████████| 10/10 [00:00<00:00, 49.60it/s]
# 100%|██████████| 20/20 [00:01<00:00, 18.20it/s]
# 100%|██████████| 19/19 [00:00<00:00, 23.08it/s]
# 100%|██████████| 32/32 [00:01<00:00, 17.47it/s]
# 100%|██████████| 10/10 [00:01<00:00,  5.24it/s]
# 100%|██████████| 10/10 [00:00<00:00, 10.90it/s]
# 100%|██████████| 10/10 [00:01<00:00,  6.64it/s]
# 100%|██████████| 19/19 [00:01<00:00, 13.53it/s]
# 100%|██████████| 20/20 [00:00<00:00, 51.10it/s]
# 100%|██████████| 19/19 [00:02<00:00,  6.46it/s]
# 100%|██████████| 36/36 [00:04<00:00,  8.63it/s]
# 100%|██████████| 10/10 [00:00<00:00, 16.69it/s]
# 100%|██████████| 10/10 [00:01<00:00,  6.16it/s]
# 100%|██████████| 11/11 [00:00<00:00, 41.43it/s]
# 100%|██████████| 10/10 [00:00<00:00, 42.62it/s]
# 100%|██████████| 20/20 [00:01<00:00, 17.80it/s]
# 100%|██████████| 7/7 [00:01<00:00,  5.94it/s]
# 100%|██████████| 21/21 [00:03<00:00,  6.19it/s]
# 100%|██████████| 12/12 [00:00<00:00, 123.28it/s]
# 516

# %%
random.shuffle(train_data)

# %%
train_imgs = []
train_labels = []

for img, label in train_data:
    train_imgs.append(img)
    train_labels.append(label)

# %%
import numpy as np
train_imgs_np = np.array(train_imgs)
train_labels_np = np.array(train_labels)

print(train_imgs_np.shape, train_labels_np.shape)
# Out:
# (516, 64, 64, 3) (516,)

# %%
train_imgs_np=train_imgs_np / 255.0

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    keras.Input(shape=(64, 64, 3)),
    layers.Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(filters=512, kernel_size=(3, 3), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 64, 64, 64)        1792
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 32, 32, 128)       73856
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 16, 16, 256)       295168
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 8, 8, 512)         1180160
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_11 (Dense)             (None, 32)                2080
# =================================================================
# Total params: 3,666,912
# Trainable params: 3,666,912
# Non-trainable params: 0
# _________________________________________________________________

# %%
learning_rate = 0.001
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
h = model.fit(x=train_imgs_np, y=train_labels_np, epochs=35, validation_split=0.4, batch_size=305)
# Out:
# Epoch 1/35
# 2/2 [==============================] - 1s 363ms/step - loss: 3.4730 - accuracy: 0.0388 - val_loss: 3.4578 - val_accuracy: 0.0386
# Epoch 2/35
# 2/2 [==============================] - 0s 235ms/step - loss: 3.4274 - accuracy: 0.0388 - val_loss: 3.4659 - val_accuracy: 0.0338
# Epoch 3/35
# 2/2 [==============================] - 0s 226ms/step - loss: 3.4419 - accuracy: 0.0421 - val_loss: 3.4772 - val_accuracy: 0.0338
# Epoch 4/35
# 2/2 [==============================] - 0s 233ms/step - loss: 3.4299 - accuracy: 0.0421 - val_loss: 3.4981 - val_accuracy: 0.0338
# Epoch 22/35
# 2/2 [==============================] - 0s 223ms/step - loss: 3.3699 - accuracy: 0.0841 - val_loss: 3.5022 - val_accuracy: 0.0531
# Epoch 23/35
# 2/2 [==============================] - 0s 223ms/step - loss: 3.3648 - accuracy: 0.0874 - val_loss: 3.5005 - val_accuracy: 0.0483
# Epoch 24/35
# 2/2 [==============================] - 0s 218ms/step - loss: 3.3602 - accuracy: 0.0841 - val_loss: 3.4899 - val_accuracy: 0.0483
# Epoch 25/35
# 2/2 [==============================] - 0s 226ms/step - loss: 3.3553 - accuracy: 0.0841 - val_loss: 3.4690 - val_accuracy: 0.0483
# Epoch 26/35
# 2/2 [==============================] - 0s 238ms/step - loss: 3.3548 - accuracy: 0.0841 - val_loss: 3.4549 - val_accuracy: 0.0483
# Epoch 27/35
# 2/2 [==============================] - 0s 226ms/step - loss: 3.3596 - accuracy: 0.0841 - val_loss: 3.4467 - val_accuracy: 0.0483
# Epoch 28/35
# 2/2 [==============================] - 0s 224ms/step - loss: 3.3685 - accuracy: 0.0841 - val_loss: 3.4430 - val_accuracy: 0.0483
# Epoch 29/35
# 2/2 [==============================] - 0s 220ms/step - loss: 3.3848 - accuracy: 0.0841 - val_loss: 3.4425 - val_accuracy: 0.0483
# Epoch 30/35
# 2/2 [==============================] - 0s 222ms/step - loss: 3.3875 - accuracy: 0.0841 - val_loss: 3.4429 - val_accuracy: 0.0483
# Epoch 31/35
# 2/2 [==============================] - 0s 223ms/step - loss: 3.3790 - accuracy: 0.0841 - val_loss: 3.4471 - val_accuracy: 0.0483
# Epoch 32/35
# 2/2 [==============================] - 0s 220ms/step - loss: 3.3671 - accuracy: 0.0841 - val_loss: 3.4604 - val_accuracy: 0.0483
# Epoch 33/35
# 2/2 [==============================] - 0s 231ms/step - loss: 3.3539 - accuracy: 0.0841 - val_loss: 3.5057 - val_accuracy: 0.0483
# Epoch 34/35
# 2/2 [==============================] - 0s 222ms/step - loss: 3.3522 - accuracy: 0.0841 - val_loss: 3.5162 - val_accuracy: 0.0483
# Epoch 35/35
# 2/2 [==============================] - 0s 215ms/step - loss: 3.3528 - accuracy: 0.0841 - val_loss: 3.4974 - val_accuracy: 0.0531

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(h.history['accuracy'], 'o-', label='train accuracy')
plt.plot(h.history['val_accuracy'], 'o-', label = 'validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

plt.subplot(1,2,2)
plt.plot(h.history['loss'], 'o-', label='train loss')
plt.plot(h.history['val_loss'], 'o-', label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc='upper right')

plt.show()

# %%
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    input_data = cv2.resize(frame, (64, 64))
    input_data = input_data / 255.0
    input_data = np.expand_dims(input_data, axis=0)

    prediction = model.predict(input_data)
    predicted_label = classes[np.argmax(prediction)]

    cv2.putText(frame, f'Prediction: {predicted_label}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.imshow('Webcam Prediction', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
